# %% [markdown]
# <a href="https://colab.research.google.com/github/HugoOchoaGonzalez/Visualizacion-de-Datos/blob/main/Clase_17_Octubre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install plotly express
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement express (from versions: none)
# ERROR: No matching distribution found for express

# %%
import plotly as px

# %%
gapminder = px.data.gapminder()

# %%
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
gapminder2007 = gapminder.query('year == 2007')
gapminder2007.head()
# Out:
#         country continent  year  lifeExp       pop     gdpPercap iso_alpha  \
# 11  Afghanistan      Asia  2007   43.828  31889923    974.580338       AFG
# 23      Albania    Europe  2007   76.423   3600523   5937.029526       ALB
# 35      Algeria    Africa  2007   72.301  33333216   6223.367465       DZA
# 47       Angola    Africa  2007   42.731  12420476   4797.231267       AGO
# 59    Argentina  Americas  2007   75.320  40301927  12779.379640       ARG
#
#     iso_num
# 11        4
# 23        8
# 35       12
# 47       24
# 59       32

# %%
labels_dict = {"lifeExp":"Life expectative", "gdpPercap":"GDP per capita (USD)"}
fig = px.scatter(gapminder)
